# %%
# %pip install nbdt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nbdt in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (0.0.4)
# Requirement already satisfied: scikit-learn in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from nbdt) (1.3.1)
# Requirement already satisfied: nltk in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from nbdt) (3.8.1)
# Requirement already satisfied: torch in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from nbdt) (2.1.0)
# Requirement already satisfied: pytorchcv in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from nbdt) (0.0.67)
# Requirement already satisfied: torchvision in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from nbdt) (0.16.0)
# Requirement already satisfied: networkx in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from nbdt) (3.1)
# Requirement already satisfied: click in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from nltk->nbdt) (8.1.7)
# Requirement already satisfied: tqdm in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from nltk->nbdt) (4.66.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from nltk->nbdt) (2023.10.3)
# Requirement already satisfied: joblib in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from nltk->nbdt) (1.3.2)
# Requirement already satisfied: requests in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from pytorchcv->nbdt) (2.31.0)
# Requirement already satisfied: numpy in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from pytorchcv->nbdt) (1.24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from requests->pytorchcv->nbdt) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from requests->pytorchcv->nbdt) (2.0.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from requests->pytorchcv->nbdt) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from requests->pytorchcv->nbdt) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from scikit-learn->nbdt) (3.2.0)
# Requirement already satisfied: scipy>=1.5.0 in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from scikit-learn->nbdt) (1.11.3)
# Requirement already satisfied: fsspec in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from torch->nbdt) (2023.9.2)
# Requirement already satisfied: filelock in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from torch->nbdt) (3.12.4)
# Requirement already satisfied: typing-extensions in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from torch->nbdt) (4.8.0)
# Requirement already satisfied: sympy in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from torch->nbdt) (1.12)
# Requirement already satisfied: jinja2 in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from torch->nbdt) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from jinja2->torch->nbdt) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from sympy->torch->nbdt) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages (from torchvision->nbdt) (9.5.0)
# WARNING: You are using pip version 21.2.4; however, version 23.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from nbdt.model import SoftNBDT
from nbdt.models import ResNet18, wrn28_10_cifar10, wrn28_10_cifar100, wrn28_10  # use wrn28_10 for TinyImagenet200
from torchvision import transforms
from nbdt.utils import DATASET_TO_CLASSES, load_image_from_path, maybe_install_wordnet
from IPython.display import display
# Out:
# stty: stdin isn't a terminal
# /Users/divyamkumar/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# not enough values to unpack (expected 2, got 0)

# %%
model = wrn28_10_cifar10()
model = SoftNBDT(
  pretrained=True,
  dataset='CIFAR10',
  arch='wrn28_10_cifar10',
  model=model)

# %%
image_urls = {
    'cat': 'https://images.pexels.com/photos/126407/pexels-photo-126407.jpeg?auto=compress&cs=tinysrgb&dpr=2&w=300',
    'bear': 'https://images.pexels.com/photos/158109/kodiak-brown-bear-adult-portrait-wildlife-158109.jpeg?auto=compress&cs=tinysrgb&dpr=2&w=300',
    'dog': 'https://images.pexels.com/photos/1490908/pexels-photo-1490908.jpeg?auto=compress&cs=tinysrgb&dpr=2&w=300'
}

# %%
# show image
im = load_image_from_path(image_urls['bear'])
display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x400>

# %%
# load + transform image
transforms = transforms.Compose([
  transforms.Resize(32),
  transforms.CenterCrop(32),
  transforms.ToTensor(),
  transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
x = transforms(im)[None]

# %%
# run inference
outputs = model(x)  # to get intermediate decisions, use `model.forward_with_decisions(x)` and add `hierarchy='wordnet' to SoftNBDT
_, predicted = outputs.max(1)
cls = DATASET_TO_CLASSES['CIFAR10'][predicted[0]]
print(cls)
# Out:
# dog
